# %% [markdown]
# # Robo Advisory Dashboard

# %%
# Import Libraries
# Install packages as needed (hashtagged below)

import pandas as pd #pip install pandas openpyxl
import plotly.express as px #pip install plotly-express
import dash #pip install dash
import dash_core_components as dcc #pip install dash-core-components
import dash_html_components as html #pip install dash-html-components
from dash.dependencies import Input,Output,State
import pandas as pd
import numpy as np
import plotly.graph_objs as go
import dash_daq as daq #pip install dash-daq
from pickle import load

# %%
app = dash.Dash(__name__, external_stylesheets=['https://codepen.io/chriddyp/pen/bWLwgP.css'])

# %%
app.layout = html.Div([
    html.Div([
        # Dashboard Name
         html.Div([
            html.H3(children='Anand Robo Advisory Dashboard'),
            html.Div([
                html.H5(children='Step 1 : Please Enter Investor Characteristics'),            
                ],style={'display': 'inline-block','vertical-align': 'top',  'width': '30%',\
                         'color':'black', 'background-color': 'LightGray'}), 
            html.Div([
                html.H5(children='Step 2 : Asset Allocation and portfolio performance'),            
                ],style={'display': 'inline-block', 'vertical-align': 'top',  \
                         'color':'white','horizontalAlign' : "left", 'width': '70%', 'background-color':'black'}), 
            ],style={'font-family': 'calibri'}),  
                 #All the Investor Characteristics
                      
       #********************Demographics Features DropDown********
         html.Div([   
          html.Div([ 
            
            html.Label('NetWorth:', style={'padding': 5}),
            dcc.Slider(
                id='NETWORTH',
                min = -1000000, max = 3000000,
                marks={-1000000: '-$1M',0: '0',100000: '$100K',250000: '$250K',500000: '$500K',1000000: '$1M',2000000: '$2M',},                
                value=10000),
              
            html.Label('NetWorth:', style={'padding': 5}),
            dcc.Slider(
                id='NETWORTH',
                min = -1000000, max = 3000000,
                marks={-1000000: '-$1M',0: '0',100000: '$100K',250000: '$250K',500000: '$500K',1000000: '$1M',2000000: '$2M',},                
                value=10000),             
              
              
              
              
              
            html.Label('Age:',style={'padding': 5}),
            dcc.Slider(
                id='Age',
                min = investors['AGE07'].min(),
                max = 70,
                marks={ 25: '25',35: '35',45: '45',55: '55',70: '70'},              
                value=25),   
            #html.Br(),
            
            html.Label('NetWorth:', style={'padding': 5}),
            dcc.Slider(
                id='Nwcat',
                #min = investors['NETWORTH07'].min(), 
                min = -1000000, max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},                
                value=10000),
            #html.Br(),
            html.Label('Income:', style={'padding': 5}),
            dcc.Slider(
                id='Inccl',
                #min = investors['INCOME07'].min(), max = investors['INCOME07'].max(),
                min = -1000000,
                max = 3000000,
                marks={-1000000: '-$1M',0: '0',500000: '$500K',1000000: '$1M',2000000: '$2M',},
                value=100000),
            
           # html.Br(),
            html.Label('Education Level (scale of 4):', style={'padding': 5}),
            dcc.Slider(
                id='Edu',
                min = investors['EDCL07'].min(), max = investors['EDCL07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=2), 
            #html.Br(),
            html.Label('Married:', style={'padding': 5}),
            dcc.Slider(
                id='Married',
                min = investors['MARRIED07'].min(), max = investors['MARRIED07'].max(),
                marks={ 1: '1',2: '2'},
                value=1), 
            #html.Br(),
            html.Label('Kids:', style={'padding': 5}),
            dcc.Slider(
                id='Kids',
                min = investors['KIDS07'].min(), max = investors['KIDS07'].max(),
                #marks={ 1: '1',2: '2',3: '3',4: '4'},
                marks=[{'label': j, 'value': j} for j in investors['KIDS07'].unique()],
                value=3), 
            #html.Br(),
            html.Label('Occupation:', style={'padding': 5}),
            dcc.Slider(
                id='Occ',
                min = investors['OCCAT107'].min(), max = investors['OCCAT107'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3),            
            #html.Br(),
            html.Label('Willingness to take Risk:', style={'padding': 5}),
            dcc.Slider(
                id='Risk',
                min = investors['RISK07'].min(), max = investors['RISK07'].max(),
                marks={ 1: '1',2: '2',3: '3',4: '4'},
                value=3), 
            #html.Br(),
            html.Button(id='investor_char_button',
                            n_clicks = 0,
                            children = 'Calculate Risk Tolerance',
                            style = {'fontSize': 14, 'marginLeft': '30px', 'color' : 'white',\
                                     'horizontal-align': 'left','backgroundColor': 'grey'}),             
            #html.Br(),            
              ],style={'width': '80%'}),           
            
            ],style={'width': '30%', 'font-family': 'calibri','vertical-align': 'top','display': 'inline-block'\
                     }),
    ])
])

# %%
if __name__ == '__main__':
    app.run_server(port = 4050)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:4050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_renderer/react@16.v1_2_2m1665739439.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_renderer/polyfill@7.v1_2_2m1665739439.7.0.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_renderer/react-dom@16.v1_2_2m1665739439.8.6.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_renderer/prop-types@15.v1_2_2m1665739439.7.2.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_core_components/dash_core_components-shared.v1_8_1m1665739439.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_core_components/dash_core_components.v1_8_1m1665739439.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_html_components/dash_html_components.v1_0_2m1665739439.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_daq/dash_daq.v0_4_0m1665739458.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-component-suites/dash_renderer/dash_renderer.v1_2_2m1665739439.min.js HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:30] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [15/Oct/2022 00:19:31] "GET /_favicon.ico?v=1.9.1 HTTP/1.1" 200 -
